# %% [markdown]
# # Working with Image

# %%
import tensorflow as tf
import matplotlib.image as mp_img
import matplotlib.pyplot as plot
import os

# %%
filename = './shiv.jpg'
image = mp_img.imread(filename)
print('Image shape: ', image.shape)
print('Image shape: ', image)

plot.imshow(image)
# Out:
# Image shape:  (450, 600, 3)
# Image shape:  [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %% [markdown]
# # Transpose an Image

# %%
x = tf.Variable(image, name='x')
init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    
    transpose = tf.transpose(x, perm=[1, 0, 2])
    # Alternate transpose for image
    # transpose = tf.image.transpose_image(x)
    
    result = sess.run(transpose)
    
    print('Transposed image shape: ', result.shape)
    plot.imshow(result)
    plot.show()
# Out:
# Transposed image shape:  (600, 450, 3)
